# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from math import factorial
import sympy as sp
from sympy import solve, Eq, Function, simplify, lambdify, sympify, evalf, Rational, nsimplify  # S, Rational, Mul, Pow,
from IPython.display import display, Latex # Math, Latex
matplotlib.rcParams.update({'font.size': 12,
                            'font.family': 'calibri',
                            'mathtext.fontset': 'stix'})
sp.interactive.printing.init_printing()

# %%
k, No, mu, B, U, T = sp.symbols('k N mu B U T'.split())
Nu, Nd = sp.symbols('N_u N_d')
E, invT, M, CB, U, kayTee = sp.symbols('S (1/T) M C_B U kT'.split())
equations = [
    Eq(E/k, sp.log(sp.factorial(No)) -
        sp.log(sp.factorial(Nu)) -
        sp.log(sp.factorial(No-Nu))),   # [0]
    Eq(E/k, No*sp.log(No) -
        Nu*sp.log(Nu) -
        (No - Nu)*sp.log(No-Nu)),       # [1]
    Eq(invT, k/(2*mu*B)*sp.log((No - U/(mu*B))/(No + U/(mu*B)))),   # [2]
    Eq(M, No*mu*sp.tanh((mu*B)/(k*T))),                             # [3]
    Eq(M, -U/B),                # [4]
    Eq(CB, No*k*(((mu*B)/(k*T))**2/(sp.cosh((mu*B)/(k*T))**2))),    # [5]
    Eq(U, (mu*B*(No - 2*Nu))),  # [6]
    Eq(U/(mu*B), No - 2*Nu),    # [7]
    Eq(kayTee/(B*mu), 2/(sp.log((No - U/(B*mu))/(No + U/(B*mu))))),        # [8]
    Eq(k, 8.62*10**(-5)),       # [9]
    Eq(mu, 5*10**(-8)),         # [10]
    Eq(T, 300),                 # [11]
    Eq(B, 1),                   # [12]
    Eq(No, 100)]                # [13]
equations
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢S                                        S
# ⎢─ = log(N!) - log(Nᵤ!) - log((N - Nᵤ)!), ─ = N⋅log(N) - Nᵤ⋅log(Nᵤ) - (N - Nᵤ)
# ⎢k                                        k
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                            ⎛     U ⎞
#                            ⎜N - ───⎟
#                            ⎜    B⋅μ⎟
#                       k⋅   ⎜───────⎟
#                            ⎜     U ⎟
#                         log⎜N + ───⎟                                         2
#                            ⎝    B⋅μ⎠              ⎛B⋅μ⎞      -U             B
# ⋅log(N - Nᵤ), (1/T) = ──────────────, M = N⋅μ⋅tanh⎜───⎟, M = ───, C_B = ──────
#                           2⋅B⋅μ                   ⎝T⋅k⎠       B          2
#                                                                         T ⋅k⋅c
#
#
#
#
#
#
#
#
#
#
#
#     2
# ⋅N⋅μ                            U               kT        2
# ─────────, U = B⋅μ⋅(N - 2⋅Nᵤ), ─── = N - 2⋅Nᵤ, ─── = ────────────, k = 8.62e-5
# ...

# %%
newM = equations[4].rhs.subs(U, equations[6].rhs)  # [13]
equations.append(Eq(M, newM))
equations
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢S                                        S
# ⎢─ = log(N!) - log(Nᵤ!) - log((N - Nᵤ)!), ─ = N⋅log(N) - Nᵤ⋅log(Nᵤ) - (N - Nᵤ)
# ⎢k                                        k
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                            ⎛     U ⎞
#                            ⎜N - ───⎟
#                            ⎜    B⋅μ⎟
#                       k⋅   ⎜───────⎟
#                            ⎜     U ⎟
#                         log⎜N + ───⎟                                         2
#                            ⎝    B⋅μ⎠              ⎛B⋅μ⎞      -U             B
# ⋅log(N - Nᵤ), (1/T) = ──────────────, M = N⋅μ⋅tanh⎜───⎟, M = ───, C_B = ──────
#                           2⋅B⋅μ                   ⎝T⋅k⎠       B          2
#                                                                         T ⋅k⋅c
#
#
#
#
#
#
#
#
#
#
#
#     2
# ⋅N⋅μ                            U               kT        2
# ─────────, U = B⋅μ⋅(N - 2⋅Nᵤ), ─── = N - 2⋅Nᵤ, ─── = ────────────, k = 8.62e-5
# ...

# %%
newNu = (Eq(Nu, (solve(equations[14], Nu))[0]))
equations.append(newNu)  # [14]
equations
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢S                                        S
# ⎢─ = log(N!) - log(Nᵤ!) - log((N - Nᵤ)!), ─ = N⋅log(N) - Nᵤ⋅log(Nᵤ) - (N - Nᵤ)
# ⎢k                                        k
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                            ⎛     U ⎞
#                            ⎜N - ───⎟
#                            ⎜    B⋅μ⎟
#                       k⋅   ⎜───────⎟
#                            ⎜     U ⎟
#                         log⎜N + ───⎟                                         2
#                            ⎝    B⋅μ⎠              ⎛B⋅μ⎞      -U             B
# ⋅log(N - Nᵤ), (1/T) = ──────────────, M = N⋅μ⋅tanh⎜───⎟, M = ───, C_B = ──────
#                           2⋅B⋅μ                   ⎝T⋅k⎠       B          2
#                                                                         T ⋅k⋅c
#
#
#
#
#
#
#
#
#
#
#
#     2
# ⋅N⋅μ                            U               kT        2
# ─────────, U = B⋅μ⋅(N - 2⋅Nᵤ), ─── = N - 2⋅Nᵤ, ─── = ────────────, k = 8.62e-5
# ...

# %%
subbedSk = Eq(E/k, (equations[1].rhs.subs(Nu, equations[15].rhs)))  #[15]
equations.append(subbedSk)
equations
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢S                                        S
# ⎢─ = log(N!) - log(Nᵤ!) - log((N - Nᵤ)!), ─ = N⋅log(N) - Nᵤ⋅log(Nᵤ) - (N - Nᵤ)
# ⎢k                                        k
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                            ⎛     U ⎞
#                            ⎜N - ───⎟
#                            ⎜    B⋅μ⎟
#                       k⋅   ⎜───────⎟
#                            ⎜     U ⎟
#                         log⎜N + ───⎟                                         2
#                            ⎝    B⋅μ⎠              ⎛B⋅μ⎞      -U             B
# ⋅log(N - Nᵤ), (1/T) = ──────────────, M = N⋅μ⋅tanh⎜───⎟, M = ───, C_B = ──────
#                           2⋅B⋅μ                   ⎝T⋅k⎠       B          2
#                                                                         T ⋅k⋅c
#
#
#
#
#
#
#
#
#
#
#
#     2
# ⋅N⋅μ                            U               kT        2
# ─────────, U = B⋅μ⋅(N - 2⋅Nᵤ), ─── = N - 2⋅Nᵤ, ─── = ────────────, k = 8.62e-5
# ...

# %%
newSk = np.zeros(101)
for i in range(101):
    newSk[i] = equations[1].rhs.subs([(Nu, i), (No, 100)])  # [15]
newSk[0] = 0; newSk[100] = 0;
newSk
# Out:
# array([  0.        ,   5.60015344,   9.80391133,  13.47421682,
#         16.79441477,  19.85152433,  22.69675225,  25.36389469,
#         27.87693718,  30.25378231,  32.50829734,  34.65153369,
#         36.69249913,  38.63867063,  40.49634851,  42.27090878,
#         43.96698794,  45.5886213 ,  47.13934868,  48.62229647,
#         50.04024235,  51.39566706,  52.69079614,  53.92763415,
#         55.10799281,  56.23351446,  57.30569171,  58.32588401,
#         59.29533174,  60.21516826,  61.08643021,  61.91006644,
#         62.68694576,  63.41786357,  64.10354779,  64.7446639 ,
#         65.34181948,  65.89556807,  66.40641266,  66.87480869,
#         67.3011667 ,  67.68585467,  68.02920002,  68.33149136,
#         68.59298003,  68.81388137,  68.99437585,  69.1346099 ,
#         69.23469671,  69.29471672,  69.31471806,  69.29471672,
#         69.23469671,  69.1346099 ,  68.99437585,  68.81388137,
#         68.59298003,  68.33149136,  68.02920002,  67.68585467,
# ...

# %%
y = equations[16].rhs.subs([(No, equations[13].rhs),
                           (mu, equations[10].rhs),
                            (M, 1)])
y
# Out:
# -1711.80956509709 + 100⋅log(100) + 9999950.0⋅ⅈ⋅π

# %%
x = (equations[7].rhs.subs(No, equations[13].rhs))
type(x)
# Out:
# sympy.core.add.Add

# %%
xFin = np.zeros(101)
for i in range(101):
    temp = (complex(x.subs(Nu, i)).real)
    xFin[i] = temp
xFin
yFin = np.ones(101)*complex(y).real
yFin;

# %%
ratio = simplify(x/y)
ratio
print(type(ratio))
# Out:
# <class 'sympy.core.mul.Mul'>

# %%
print(type(x), type(y))
print(type(xFin), type(yFin))
yFin
print(xFin.shape, yFin.shape)
display(x, y)
# Out:
# <class 'sympy.core.add.Add'> <class 'sympy.core.add.Add'>
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (101,) (101,)
# -2⋅Nᵤ + 100
# -1711.80956509709 + 100⋅log(100) + 9999950.0⋅ⅈ⋅π

# %%
ratio
# Out:
#                  -(2⋅Nᵤ - 100)
# ────────────────────────────────────────────────
# -1711.80956509709 + 100⋅log(100) + 9999950.0⋅ⅈ⋅π

# %%
multiplicity = sp.factorial(No)/(sp.factorial(Nu)*(sp.factorial(No - Nu)))
multi = np.zeros(101)
for i in range(101):
    multi[i] = (factorial(100)/(factorial(i)*(factorial(100-i))))
multi
yAxis = np.log(multi)

# %%
fig, ax = plt.subplots(figsize=(20, 8))
ax.set_ylabel("S/k", fontsize=18)
ax.set_xlabel('U/mu*B', fontsize=18)
# ax.spines["top"].set_visible(False)
# ax.spines["bottom"].set_visible(False)
# ax.spines["right"].set_visible((False)
# ax.spines["left"].set_visible(False)
# ax.get_xaxis().tick_bottom()
# ax.get_yaxis().tick_left()

# plt.xlabel('$\Delta t$ $(s)$',fontsize=20)
# plt.ylabel('$\Delta p$ $(hPa)$',fontsize=20)
# plt.tick_params(axis="both", which="both", bottom="off", top="off",
#                 labelbottom="on", left="off", right="off", labelleft="on")
plt.title('Entropy as a Function of Energy', fontsize=22)
plt.plot(xFin, yAxis)
plt.show()

# %%
y = (equations[8].rhs.subs([(U, equations[6].rhs), (B, 1), (mu, equations[10].rhs), (No, 100)]))
type(y)
# Out:
# sympy.core.mul.Mul

# %%
y
# Out:
#        2
# ────────────────
#    ⎛    2⋅Nᵤ   ⎞
# log⎜───────────⎟
#    ⎝-2⋅Nᵤ + 200⎠

# %%
Y = lambdify(Nu, y)

YFIN = np.zeros(100)
for i in range(1,50):
    YFIN[i] = Y(i)
    for j in range(51,99):
        YFIN[j] = Y(j)
YFIN
# Out:
# array([  0.        ,  -0.43524436,  -0.51389834,  -0.57535766,
#         -0.62931596,  -0.67924654,  -0.72686692,  -0.7731891 ,
#         -0.81888445,  -0.86444061,  -0.91023923,  -0.9565986 ,
#         -1.0037993 ,  -1.05210068,  -1.10175236,  -1.15300287,
#         -1.2061067 ,  -1.26133048,  -1.31895889,  -1.37930067,
#         -1.44269504,  -1.50951893,  -1.58019526,  -1.65520272,
#         -1.73508767,  -1.82047845,  -1.91210337,  -2.010813  ,
#         -2.11760857,  -2.23367839,  -2.360445  ,  -2.49962724,
#         -2.65332292,  -2.82412058,  -3.01525318,  -3.23081313,
#         -3.4760595 ,  -3.757867  ,  -4.08539935,  -4.47114995,
#         -4.93260692,  -5.49502817,  -6.19629761,  -7.09594403,
#         -8.29317856,  -9.96657731, -12.47328767, -16.64664743,
#        -24.98666097, -49.99333262,   0.        ,  49.99333262,
#         24.98666097,  16.64664743,  12.47328767,   9.96657731,
#          8.29317856,   7.09594403,   6.19629761,   5.49502817,
# ...

# %%
#k=8.62⋅10−5,μ=5.0⋅10−8,T=300,B=1,N=100
#np.ones(100)*(8.62*10**(-5)*300/(5*10**(-8)*1))
tempVenergyY = YFIN
tempVenergyX = XFIN
fig, ax = plt.subplots(figsize=(20, 8))
ax.set_ylabel("S/k", fontsize=18)
ax.set_xlabel('U/mu*B', fontsize=18)
# ax.spines["top"].set_visible(False)
# ax.spines["bottom"].set_visible(False)
# ax.spines["right"].set_visible((False)
# ax.spines["left"].set_visible(False)
# ax.get_xaxis().tick_bottom()
# ax.get_yaxis().tick_left()

# plt.xlabel('$\Delta t$ $(s)$',fontsize=20)
# plt.ylabel('$\Delta p$ $(hPa)$',fontsize=20)
# plt.tick_params(axis="both", which="both", bottom="off", top="off",
#                 labelbottom="on", left="off", right="off", labelleft="on")
plt.title('Entropy as a Function of Energy', fontsize=22)
plt.plot(tempVenergyY)
plt.show()

# %%
equations[5] = Eq(CB/(No*k), B**2*mu**2/(T**2*k**2*sp.cosh(B*mu/(T*k))**2))
equations
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢S                                        S
# ⎢─ = log(N!) - log(Nᵤ!) - log((N - Nᵤ)!), ─ = N⋅log(N) - Nᵤ⋅log(Nᵤ) - (N - Nᵤ)
# ⎢k                                        k
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                            ⎛     U ⎞
#                            ⎜N - ───⎟
#                            ⎜    B⋅μ⎟
#                       k⋅   ⎜───────⎟
#                            ⎜     U ⎟
#                         log⎜N + ───⎟
#                            ⎝    B⋅μ⎠              ⎛B⋅μ⎞      -U   C_B        B
# ⋅log(N - Nᵤ), (1/T) = ──────────────, M = N⋅μ⋅tanh⎜───⎟, M = ───, ─── = ──────
#                           2⋅B⋅μ                   ⎝T⋅k⎠       B   N⋅k    2  2
#                                                                         T ⋅k ⋅
#
#
#
#
#
#
#
#
#
#
#
# 2  2
#  ⋅μ                              U               kT        2
# ──────────, U = B⋅μ⋅(N - 2⋅Nᵤ), ─── = N - 2⋅Nᵤ, ─── = ────────────, k = 8.62e-
# ...

# %%
temp0rs = (equations[8].rhs.subs([(U, equations[6].rhs), (No, 100)]))**(-1)
temp = Eq(CB/(No*k), (temp0rs)**2/(sp.cosh(temp0rs)**2))
# temp.rhs.subs(U, equations[6].rhs).simplify
pltz = np.zeros(101)
for i in range(101):
    pltz[i] = temp.rhs.subs(Nu, i)
pltz
# Out:
# array([             nan,   2.09039752e-01,   2.96866799e-01,
#          3.51622927e-01,   3.87841004e-01,   4.11811743e-01,
#          4.27001387e-01,   4.35581611e-01,   4.39028345e-01,
#          4.38403049e-01,   4.34501626e-01,   4.27940317e-01,
#          4.19208553e-01,   4.08703160e-01,   3.96751431e-01,
#          3.83627205e-01,   3.69562416e-01,   3.54755570e-01,
#          3.39378113e-01,   3.23579291e-01,   3.07489929e-01,
#          2.91225398e-01,   2.74887991e-01,   2.58568828e-01,
#          2.42349418e-01,   2.26302930e-01,   2.10495262e-01,
#          1.94985919e-01,   1.79828758e-01,   1.65072623e-01,
#          1.50761869e-01,   1.36936832e-01,   1.23634212e-01,
#          1.10887415e-01,   9.87268487e-02,   8.71801707e-02,
#          7.62725144e-02,   6.60266792e-02,   5.64632987e-02,
#          4.76009876e-02,   3.94564689e-02,   3.20446855e-02,
#          2.53788966e-02,   1.94707616e-02,   1.43304115e-02,
# ...

# %%
temp
# Out:
#              2⎛    2⋅Nᵤ   ⎞
#           log ⎜───────────⎟
# C_B           ⎝-2⋅Nᵤ + 200⎠
# ─── = ─────────────────────────
# N⋅k          ⎛   ⎛    2⋅Nᵤ   ⎞⎞
#              ⎜log⎜───────────⎟⎟
#             2⎜   ⎝-2⋅Nᵤ + 200⎠⎟
#       4⋅cosh ⎜────────────────⎟
#              ⎝       2        ⎠

# %%
temp0rs
# Out:
#        2
# ────────────────
#    ⎛    2⋅Nᵤ   ⎞
# log⎜───────────⎟
#    ⎝-2⋅Nᵤ + 200⎠

# %%
# Y2FIN = np.ones(100)*equations[5].rhs.subs([(B, 1), (mu, equations[10].rhs), (T, 300), (k, equations[9].rhs),])

# %%
# Y2FIN

# %%
#k=8.62⋅10−5,μ=5.0⋅10−8,T=300,B=1,N=100
#np.ones(100)*(8.62*10**(-5)*300/(5*10**(-8)*1))
tempVenergyY = YFIN
tempVenergyX = XFIN
fig, ax = plt.subplots(figsize=(20, 8))
ax.set_ylabel("C/Nk", fontsize=18)
ax.set_xlim(0,50)
ax.set_xlabel('kT/$\mu$B', fontsize=18)
# ax.spines["top"].set_visible(False)
# ax.spines["bottom"].set_visible(False)
# ax.spines["right"].set_visible((False)
# ax.spines["left"].set_visible(False)
# ax.get_xaxis().tick_bottom()
# ax.get_yaxis().tick_left()

# plt.xlabel('$\Delta t$ $(s)$',fontsize=20)
# plt.ylabel('$\Delta p$ $(hPa)$',fontsize=20)
# plt.tick_params(axis="both", which="both", bottom="off", top="off",
#                 labelbottom="on", left="off", right="off", labelleft="on")
plt.title('Heat Capacity of a Two-State Paramagnet', fontsize=22)
plt.plot(pltz)
plt.show()

# %%
lasteqy = Eq(M/(No*mu), -1 + 2*(Nu/No))
lasteqy
lasteqx = Eq(k*T/(B*mu), equations[8].rhs.subs([(U, equations[6].rhs), (No, 100)]))
rizzers = (Eq((k*T/(mu*B))/M/(No*mu), lasteqx.rhs/lasteqy.rhs))

Y = lambdify(Nu, rizzers.rhs)
print(type(rizzers.rhs))
plzzers = np.zeros(101)
# for i in range(1,5):
#     plzzers[i] = Y(i)
#     print(plzzers)
# plzzers




# for i in range(101):
#     plzzers[i] = rizzers.rhs.subs(Nu, i).evalf()
# #     yizzers[i] = lasteqy.rhs.subs([(No, 100), (Nu, i)])
# #     xizzers[i] = lasteqx.rhs.subs(Nu, i)
# print(sp.srepr(rizzers.rhs.as_independent()[0]))
rizzers.rhs
# Out:
# <class 'sympy.core.mul.Mul'>
#              2
# ────────────────────────────
# ⎛     2⋅Nᵤ⎞    ⎛    2⋅Nᵤ   ⎞
# ⎜-1 + ────⎟⋅log⎜───────────⎟
# ⎝      N  ⎠    ⎝-2⋅Nᵤ + 200⎠

# %%
# %reset

# %%
Spread = np.linspace(0,100,101)
Latex(x)
func = equations[7].rhs.subs(No, equations[12].rhs)(Nu)
f = lambdify(Nu, func, "numpy")
f(Spread)
